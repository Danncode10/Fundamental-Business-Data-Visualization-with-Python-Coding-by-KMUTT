# %% [markdown]
# #### Lester Dann G. Lopez
# #### Nueva Vizcaya State University Philippines
# #### Date: November 22, 2025
#
# # Exercise 1: Data Collection
#
# ![Question](Question_Data_Collection.png)

# %%
import pandas as pd

# %% [markdown]
# ### 1. Make List of names
#
# Write a program to create a list of names; then define a function to display all the elements in the received list. Call the function to execute its statements and display all
# names in the list. (Names: Ahmed, Ali, Salim, Abdullah, and Salwa)

# %%
names = ["Ahmed", "Ali", "Salim", "Abdulla", "Salwa"]
print(names)
# Out:
# ['Ahmed', 'Ali', 'Salim', 'Abdulla', 'Salwa']

# %% [markdown]
# ### 3. Create a Series of grades
#
# Write a program to create a series to maintain five students' names above and GPA values.
# (GPA: 2.5, 3.0, 2.5, 3.5, 4.0)

# %%
grades = pd.Series([2.5, 3.0, 2.5, 3.5, 4.0])
print(grades)
# Out:
# 0    2.5
# 1    3.0
# 2    2.5
# 3    3.5
# 4    4.0
# dtype: float64

# %% [markdown]
# ### 3. Create dataframe
#
# Write a program to create a data frame to maintain three students' names associated with their grades in three courses and then add a new column named Mean to maintain the
# calculated mean mark per course. Display the final data frame.

# %%
table = pd.DataFrame({
    "": ["Course1", "Course2", "Course3"],
    "Ahmed": [65, 60, 78],
    "Ali": [70, 78, 80],
    "Salim": [69, 68, 72],
    "Abdullah": [75, 80, 84],
    "Salwa": [92, 94, 98],
})

# Set 'Course1' as index
table = table.set_index("")  # or use table.set_index("Course1", inplace=True)

print(table)
# Out:
#          Ahmed  Ali  Salim  Abdullah  Salwa
#
# Course1     65   70     69        75     92
# Course2     60   78     68        80     94
# Course3     78   80     72        84     98

# %%
table["Mean"] = table.mean(axis=1)
print(table)
# Out:
#          Ahmed  Ali  Salim  Abdullah  Salwa  Mean
#
# Course1     65   70     69        75     92  74.2
# Course2     60   78     68        80     94  76.0
# Course3     78   80     72        84     98  82.4
